# %%
# pip install jsonlines
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import json
import jsonlines

# %%
full_csv = pd.read_csv("../preprocessed_data_level1/chats/preprocessed_full.csv").drop(columns="Unnamed: 0")

# %%
# full_dictionary.append(
#         {
#             "Context":
#                 full_csv["input"][116],
#             "Knowledge":
#                 "",
#             "Response":
#                 full_csv["output"][116]
#         }
#     )

# %%
full_dictionary = []

# %%
for i in range(full_csv.__len__()):
    full_dictionary.append(
        {
            "Context":
                full_csv["input"][i],
            "Knowledge":
                "",
            "Response":
                full_csv["output"][i]
        }
    )

# %%
full_dictionary
# Out:
# [{'Context': 'Hi',
#   'Knowledge': '',
#   'Response': 'Hello there. Tell me how are you feeling today?'},
#  {'Context': 'Hi',
#   'Knowledge': '',
#   'Response': 'Hi there. What brings you here today?'},
#  {'Context': 'Hi',
#   'Knowledge': '',
#   'Response': 'Hi there. How are you feeling today?'},
#  {'Context': 'Hi',
#   'Knowledge': '',
#   'Response': 'Great to see you. How do you feel currently?'},
#  {'Context': 'Hi',
#   'Knowledge': '',
#   'Response': "Hello there. Glad to see you're back. What's going on in your world right now?"},
#  {'Context': 'Hey',
#   'Knowledge': '',
#   'Response': 'Hello there. Tell me how are you feeling today?'},
#  {'Context': 'Hey',
#   'Knowledge': '',
#   'Response': 'Hi there. What brings you here today?'},
#  {'Context': 'Hey',
#   'Knowledge': '',
#   'Response': 'Hi there. How are you feeling today?'},
#  {'Context': 'Hey',
#   'Knowledge': '',
#   'Response': 'Great to see you. How do you feel currently?'},
#  {'Context': 'Hey',
# ...

# %%
with jsonlines.open(file="../preprocessed_data_level1/chats/formatted_for_training.jsonl", mode="w") as writer:
    for e in full_dictionary:
        writer.write(e)
